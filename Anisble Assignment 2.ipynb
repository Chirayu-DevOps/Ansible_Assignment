# %% [markdown]
# Write Ansible playbooks to automate the setup and configuration of a web server (e.g., Apache or Nginx)?
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# nginx

# %% [markdown]
# ![image.png](data:image/png;base64,...)
